# %% [markdown]
# ## Desde PowerShell
#
# ## Activar los Scripts-->   Comando: Set-ExecutionPolicy Unrestricted
#
# ## Desactivar los Scripts --> Comando: Set-ExecutionPolicy Restricted

# %% [markdown]
# python -m venv env -->VS

# %% [markdown]
# # Crear un entorno virtual en python
# ## Desde VS

# %% [markdown]
# env\Scripts\activate

# %% [markdown]
# deactivate

# %% [markdown]
# ## Instalando una biblioteca
