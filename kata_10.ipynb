# %% [markdown]
# Tracebacks

# %%
open("/path/to/mars.jpg")
Traceback (most recent call last):
  File "<stdin>", line 1, in <module>
FileNotFoundError: [Errno 2] No such file or directory: '/path/to/mars.jpg'
# Out:
#   Input In [2]
#     Traceback (most recent call last):
#                ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
def main():
    open("/path/to/mars.jpg")

if __name__ == '__main__':
    main()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# g:\Mi unidad\LX\kata_10\modulo10.ipynb Cell 3' in <module>
#       <a href='vscode-notebook-cell:/g%3A/Mi%20unidad/LX/kata_10/modulo10.ipynb#ch0000003?line=1'>2</a>     open("/path/to/mars.jpg")
#       <a href='vscode-notebook-cell:/g%3A/Mi%20unidad/LX/kata_10/modulo10.ipynb#ch0000003?line=3'>4</a> if __name__ == '__main__':
# ----> <a href='vscode-notebook-cell:/g%3A/Mi%20unidad/LX/kata_10/modulo10.ipynb#ch0000003?line=4'>5</a>     main()
#
# g:\Mi unidad\LX\kata_10\modulo10.ipynb Cell 3' in main()
#       <a href='vscode-notebook-cell:/g%3A/Mi%20unidad/LX/kata_10/modulo10.ipynb#ch0000003?line=0'>1</a> def main():
# ----> <a href='vscode-notebook-cell:/g%3A/Mi%20unidad/LX/kata_10/modulo10.ipynb#ch0000003?line=1'>2</a>     open("/path/to/mars.jpg")
#
# FileNotFoundError: [Errno 2] No such file or directory: '/path/to/mars.jpg'

# %%
$ python3 open.py
Traceback (most recent call last):
  File "/tmp/open.py", line 5, in <module>
    main()
  File "/tmp/open.py", line 2, in main
    open("/path/to/mars.jpg")
FileNotFoundError: [Errno 2] No such file or directory: '/path/to/mars.jpg'
# Out:
#   Input In [4]
#     $ python3 open.py
#     ^
# SyntaxError: invalid syntax
